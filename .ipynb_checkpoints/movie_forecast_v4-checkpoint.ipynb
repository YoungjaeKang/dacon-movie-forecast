# %% [markdown]
# # Import Libraries

# %%
import datetime
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import Image

plt.style.use('seaborn')
sns.set(font_scale=2.0)

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import KFold
from sklearn.utils import shuffle

import xgboost as xgb

import warnings
warnings.filterwarnings('ignore')

# %%
# 자릿수 설정
pd.set_option('display.float_format', '{:,.0f}'.format)

# %% [markdown]
# # Load Dataset

# %%
df_train = pd.read_csv('data/movies_train.csv')
df_test = pd.read_csv('data/movies_test.csv')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           600 non-null    object
#  1   distributor     600 non-null    object
#  2   genre           600 non-null    object
#  3   release_time    600 non-null    object
#  4   time            600 non-null    int64
#  5   screening_rat   600 non-null    object
#  6   director        600 non-null    object
#  7   dir_prev_bfnum  270 non-null    float64
#  8   dir_prev_num    600 non-null    int64
#  9   num_staff       600 non-null    int64
#  10  num_actor       600 non-null    int64
#  11  box_off_num     600 non-null    int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 56.4+ KB

# %%
df_train.head(3)
# Out:
#        title distributor genre release_time  time screening_rat director  \
# 0     개들의 전쟁    롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1       내부자들      (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2  은밀하게 위대하게      (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
#
#    dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# 0             NaN             0         91          2        23398
# 1       1,161,602             2        387          3      7072501
# 2         220,775             4        343          4      6959083

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           243 non-null    object
#  1   distributor     243 non-null    object
#  2   genre           243 non-null    object
#  3   release_time    243 non-null    object
#  4   time            243 non-null    int64
#  5   screening_rat   243 non-null    object
#  6   director        243 non-null    object
#  7   dir_prev_bfnum  107 non-null    float64
#  8   dir_prev_num    243 non-null    int64
#  9   num_staff       243 non-null    int64
#  10  num_actor       243 non-null    int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.0+ KB

# %%
df_test.head(3)
# Out:
#          title distributor   genre release_time  time screening_rat director  \
# 0       용서는 없다      시네마서비스     느와르   2010-01-07   125      청소년 관람불가      김형준
# 1  아빠가 여자를 좋아해      (주)쇼박스  멜로/로맨스   2010-01-14   113       12세 관람가      이광재
# 2          하모니   CJ 엔터테인먼트     드라마   2010-01-28   115       12세 관람가      강대규
#
#    dir_prev_bfnum  dir_prev_num  num_staff  num_actor
# 0         300,529             2        304          3
# 1         342,700             4        275          3
# 2       4,206,611             3        419          7

# %% [markdown]
# # Explore Dataset

# %% [markdown]
# ## 결측치 확인

# %%
df_train.isnull().sum()
# Out:
# title               0
# distributor         0
# genre               0
# release_time        0
# time                0
# screening_rat       0
# director            0
# dir_prev_bfnum    330
# dir_prev_num        0
# num_staff           0
# num_actor           0
# box_off_num         0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# title               0
# distributor         0
# genre               0
# release_time        0
# time                0
# screening_rat       0
# director            0
# dir_prev_bfnum    136
# dir_prev_num        0
# num_staff           0
# num_actor           0
# dtype: int64

# %% [markdown]
# - dir_prev_bfnum 외에는 결측치가 없어 수월하다. 다만, train 데이터의 dir_prev_bfnum은 결측치가 50%를 초과했으므로 추후 drop해야 할 지 검토가 필요하다.

# %% [markdown]
# ## label 확인 : box_off_num
# - Label, 관객 수

# %%
df_train[['box_off_num']].describe()
# Out:
#        box_off_num
# count          600
# mean       708,182
# std      1,828,006
# min              1
# 25%          1,297
# 50%         12,591
# 75%        479,887
# max     14,262,766

# %%
df_train['box_off_num'].sort_values().reset_index(drop=True).plot(figsize=(10, 4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 모든 변수 상관분석

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           600 non-null    object
#  1   distributor     600 non-null    object
#  2   genre           600 non-null    object
#  3   release_time    600 non-null    object
#  4   time            600 non-null    int64
#  5   screening_rat   600 non-null    object
#  6   director        600 non-null    object
#  7   dir_prev_bfnum  270 non-null    float64
#  8   dir_prev_num    600 non-null    int64
#  9   num_staff       600 non-null    int64
#  10  num_actor       600 non-null    int64
#  11  box_off_num     600 non-null    int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 56.4+ KB

# %%
heatmap_data = df_train[['time','dir_prev_bfnum','dir_prev_num','num_staff','num_actor','box_off_num']]

# %%
heatmap_data.corr()
# Out:
#                 time  dir_prev_bfnum  dir_prev_num  num_staff  num_actor  \
# time               1               0             0          1          0
# dir_prev_bfnum     0               1             0          0          0
# dir_prev_num       0               0             1          0          0
# num_staff          1               0             0          1          0
# num_actor          0               0             0          0          1
# box_off_num        0               0             0          1          0
#
#                 box_off_num
# time                      0
# dir_prev_bfnum            0
# dir_prev_num              0
# num_staff                 1
# num_actor                 0
# box_off_num               1

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(10, 8))

plt.title('Pearson Correalation of Features', y=1.05, size=15)

sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0
            , square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={'size': 16}, fmt='.2f')
# Out:
# <AxesSubplot:title={'center':'Pearson Correalation of Features'}>

# %% [markdown]
# ## title
# - 제목

# %%
# 영화 제목은 모두 달라서 삭제해야 할 것 같다.
len(df_train['title'].unique())
# Out:
# 600

# %%
# 그래도 혹시 제목에 포함된 단어만으로 그룹핑을 하거나 제목의 길이에 따른 관객 수 차이가 있는지?
# 영화 제목 길이와 관객 수 간의 상관관계 확인해보기

result = []
for i in range(0, 600):
    word_length = len(df_train['title'][i])
    result.append(word_length)

print(result)
# Out:
# [6, 4, 9, 8, 4, 14, 4, 3, 15, 5, 6, 5, 2, 1, 7, 6, 2, 8, 2, 3, 9, 11, 2, 6, 6, 2, 6, 17, 3, 16, 6, 4, 6, 7, 6, 8, 6, 3, 8, 4, 8, 5, 6, 17, 4, 8, 5, 7, 3, 26, 2, 3, 24, 12, 2, 7, 3, 7, 7, 4, 27, 4, 4, 2, 11, 4, 3, 10, 20, 7, 8, 9, 6, 17, 3, 13, 7, 3, 7, 5, 2, 6, 2, 4, 5, 6, 3, 4, 13, 3, 4, 3, 18, 7, 6, 2, 3, 3, 6, 8, 3, 2, 2, 7, 3, 2, 1, 9, 5, 5, 3, 2, 18, 8, 3, 4, 6, 14, 7, 4, 8, 3, 3, 10, 2, 17, 7, 6, 17, 3, 20, 3, 6, 2, 4, 7, 8, 6, 2, 3, 5, 15, 6, 2, 12, 5, 2, 5, 5, 1, 7, 14, 2, 6, 11, 4, 7, 2, 5, 22, 4, 5, 2, 8, 11, 5, 3, 9, 2, 6, 4, 16, 2, 8, 9, 9, 8, 3, 16, 3, 10, 4, 2, 17, 4, 4, 3, 8, 12, 3, 6, 21, 4, 4, 4, 12, 8, 2, 15, 9, 4, 7, 8, 8, 19, 8, 8, 15, 2, 2, 4, 9, 5, 4, 4, 9, 6, 2, 6, 8, 3, 2, 2, 3, 10, 4, 7, 8, 2, 9, 6, 13, 8, 11, 4, 9, 7, 2, 5, 14, 6, 7, 5, 4, 9, 7, 2, 7, 9, 2, 8, 2, 9, 5, 3, 9, 5, 6, 3, 3, 13, 3, 11, 7, 10, 16, 8, 15, 7, 2, 7, 9, 4, 3, 6, 7, 2, 12, 2, 3, 10, 6, 2, 5, 7, 12, 4, 9, 2, 8, 7, 3, 8, 2, 5, 6, 3, 10, 4, 4, 6, 10, 8, 2, 9, 10, 8, 8, 3, 6, 6, 17, 1, 11, 10, 8, 12, 4, 6, 9, 6, 16, 4, 6, 2, 8, 6, 5, 7, 3, 5, 6, 4, 3, 5, 14, 22, 2, 11, 3, 4, 7, 8, 4, 4, 11, 12, 8, 6, 6, 6, 7, 3, 1, 15, 4, 13, 4, 5, 6, 3, 3, 3, 5, 6, 2, 4, 4, 7, 10, 20, 4, 4, 9, 6, 7, 9, 12, 3, 16, 2, 9, 6, 8, 5, 3, 3, 3, 4, 2, 5, 8, 4, 5, 30, 10, 8, 7, 3, 6, 4, 11, 2, 2, 8, 8, 9, 4, 3, 7, 10, 2, 3, 10, 5, 4, 3, 3, 3, 6, 11, 8, 6, 3, 2, 2, 18, 8, 11, 6, 14, 2, 7, 3, 5, 2, 14, 5, 2, 4, 13, 5, 7, 6, 3, 3, 6, 7, 14, 7, 4, 7, 18, 9, 13, 10, 10, 4, 4, 7, 11, 16, 14, 9, 2, 8, 6, 3, 4, 8, 4, 7, 4, 6, 6, 5, 6, 2, 11, 4, 6, 2, 16, 5, 8, 6, 7, 2, 9, 8, 8, 11, 6, 4, 2, 2, 4, 6, 2, 4, 9, 2, 6, 6, 7, 12, 5, 10, 10, 5, 4, 4, 5, 4, 2, 6, 4, 3, 8, 3, 10, 10, 12, 6, 4, 11, 11, 4, 1, 8, 7, 8, 7, 7, 6, 5, 3, 5, 5, 11, 2, 8, 6, 9, 10, 7, 10, 3, 9, 6, 3, 15, 6, 7, 6, 2, 5, 2, 17, 9, 2, 4, 7, 5, 8, 5, 6, 12, 2, 4, 4, 4, 8, 8, 7, 5, 4, 8, 20, 3, 5, 16, 18, 2, 4, 8, 2, 7, 3, 3, 5, 8, 5, 10, 8, 2, 4, 5, 6, 3]

# %%
df_train_title = df_train.copy()
df_train_title['title_length'] = result
df_train_title.head()
# Out:
#        title   distributor genre release_time  time screening_rat director  \
# 0     개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1       내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2  은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3   나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4       불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
#
#    dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num  \
# 0             NaN             0         91          2        23398
# 1       1,161,602             2        387          3      7072501
# 2         220,775             4        343          4      6959083
# 3          23,894             2         20          6       217866
# 4               1             1        251          2       483387
#
#    title_length
# 0             6
# 1             4
# 2             9
# 3             8
# 4             4

# %%
plt.scatter(x=df_train_title['title_length'], y=df_train_title['box_off_num'], alpha=0.5)

# %%
# 상관분석 결과 -0.08로 큰 의미가 없을 것 같다.
title_box_corr = df_train_title[['title_length','box_off_num']].corr(method='pearson')
title_box_corr
# Out:
#               title_length  box_off_num
# title_length             1           -0
# box_off_num             -0            1

# %%
f, ax = plt.subplots(1, 1, figsize=(5, 4))

sns.heatmap(title_box_corr,
           annot = True,
           cmap = 'summer_r', 
           vmin = -1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## distributor
# - 배급사

# %%
# unique를 찍어보면 역시나 엄청 많다
df_train['distributor'].unique()
# Out:
# array(['롯데엔터테인먼트', '(주)쇼박스', '(주)NEW', '쇼박스(주)미디어플렉스', '백두대간',
#        '유니버설픽쳐스인터내셔널코리아', '(주)두타연', '(주) 케이알씨지', '(주)콘텐츠 윙', '(주)키노아이',
#        '(주)팝 파트너스', 'CJ E&M 영화부문', '(주) 영화제작전원사', 'CJ E&M Pictures',
#        'CGV 무비꼴라쥬', '리틀빅픽처스', '스폰지', 'CJ 엔터테인먼트', 'CGV아트하우스', '조이앤시네마',
#        '인디플러그', '콘텐츠판다', '인디스토리', '(주)팝엔터테인먼트', '시네마서비스', '웃기씨네',
#        '영화사 진진', '(주)레인보우 팩토리', '김기덕 필름', 'NEW', 'CJ CGV',
#        '동국대학교 충무로영상제작센터', 'BoXoo 엔터테인먼트', '(주)마운틴픽쳐스', 'CGV 아트하우스',
#        '메가박스(주)플러스엠', '골든타이드픽처스', '파이오니아21', '디 씨드', '드림팩트 엔터테인먼트', '시너지',
#        '디마엔터테인먼트', '판다미디어', '(주)스톰픽쳐스코리아', '(주)예지림 엔터테인먼트', '(주) 영화사조제',
#        '보람엔터테인먼트', '(주)시네마달', '노바엔터테인먼트', '(주)패스파인더씨앤씨', '(주)대명문화공장',
#        '(주)온비즈넷', 'KT&G 상상마당', '무비꼴라쥬', '인벤트 디', '씨네그루(주)키다리이엔티',
#        '스튜디오후크', '시네마 달', '나이너스엔터테인먼트(주)', 'THE 픽쳐스', '영구아트무비', '리틀빅픽쳐스',
#        '어뮤즈', '이모션 픽처스', '(주)이스트스카이필름', '필라멘트 픽쳐스', '조이앤컨텐츠그룹', '타임스토리그룹',
#        '마운틴 픽처스', '(주)휘엔터테인먼트', '이십세기폭스코리아(주)', '(주)피터팬픽쳐스', '에스와이코마드',
#        '(주)더픽쳐스', '오퍼스픽쳐스', '(주)고앤고 필름', '사람과 사람들', '(주)JK필름',
#        '씨너스엔터테인먼트(주)', 'KT', '싸이더스FNH', '(주)프레인글로벌', '나우콘텐츠', '홀리가든',
#        '(주) 브릿지웍스', '(주)엣나인필름', '위더스필름', '시네마달', '(주)에이원 엔터테인먼트',
#        'OAL(올)', '싸이더스', '전망좋은영화사', '스토리셋', '이상우필름', '씨네굿필름', '영희야놀자',
#        '찬란', '어썸 피플', '아방가르드 필름', '스크린조이', '와이드릴리즈(주)', 'tvN',
#        '(주) 액티버스엔터테인먼트', '더픽쳐스/(주)마운틴픽쳐스', '제나두 엔터테인먼트', '(주)아이필름코퍼레이션',
#        '쟈비스미디어', '트리필름', '에스피엠', '(주)리틀빅픽처스', '건시네마', '키노엔터테인먼트',
#        '(주)아우라픽처스', '에이블엔터테인먼트', '드림로드', '인피니티엔터테인먼트', '새인컴퍼니',
#        '스튜디오 느림보', '와이드 릴리즈(주)', '필름라인', 'M2픽처스', '고구마공작소', '(주)미디어데이',
#        '마노엔터테인먼트', '화앤담이엔티', '(주)스마일이엔티', '(주)패뷸러스', '싸이더스 FNH', '영화사 조아',
#        '판씨네마(주)', '두 엔터테인먼트', '(주)마인스 엔터테인먼트', '전주국제영화제', '(주)마인스엔터테인먼트',
#        '상구네 필름', '케이엠스타', '(주)유비네트워크', '한국YWCA연합회', 'KBS미디어(주)', '더 피플',
#        '위드시네마', '팜코리아미디어', '(주)씨엠닉스', 'SBS콘텐츠허브', '인터콘미디어', '(주)유비콘텐츠',
#        '프로젝트 엠피', '하준사', '(주)노버스엔터테인먼트', '주머니필름', '롤러코스터 프로덕션', 'SK플래닛',
#        '서울독립영화제', '스튜디오 블루', '(주)랠리버튼', '(주)드림팩트엔터테인먼트', '에이원 엔터테인먼트',
#        '머스트 씨 무비', 'SK텔레콤(주)', '마법사필름', '스폰지이엔티', '(주)로드하우스', '미라클 필름',
#        '프리비젼 엔터테인먼트', '영화사 廊', '크리에이티브컴즈(주)', 'ysfilm', '이달투', '퍼스트런'],
#       dtype=object)

# %%
len(df_train['distributor'].unique())
# Out:
# 169

# %% [markdown]
# - 배급사는 169개가 있으므로, title과 달리 배급사와 영화는 일대다 관계
# - 즉, 어떤 배급사에서는 다른 배급사보다 더 많은 영화를 배급했을 것이고, 이는 배급사의 영향력, 회사 규모와 관련이 있을 것이다.
# - 배급한 영화 수가 많은 경우 해당 영화의 영화관을 더 많이 확보했을 가능성이 높으므로, 관객 수와 비례 관계가 있을 것으로 생각해볼수도 있겠다.

# %%
# 배급사별 영화 수 확인
df_train.groupby('distributor')['box_off_num'].sum().sort_values(ascending=False)
# Out:
# distributor
# CJ 엔터테인먼트          116788093
# (주)쇼박스              88053064
# (주)NEW              65532145
# 롯데엔터테인먼트            64383745
# CJ E&M Pictures      8244674
#                      ...
# 나우콘텐츠                     54
# 위드시네마                     46
# 사람과 사람들                   42
# 고구마공작소                     8
# 인피니티엔터테인먼트                 2
# Name: box_off_num, Length: 169, dtype: int64

# %%
df_train_distributor_group = pd.DataFrame(df_train.groupby('distributor')['box_off_num'].sum().sort_values(ascending=False))
df_train_distributor_group
# Out:
#                  box_off_num
# distributor
# CJ 엔터테인먼트          116788093
# (주)쇼박스              88053064
# (주)NEW              65532145
# 롯데엔터테인먼트            64383745
# CJ E&M Pictures      8244674
# ...                      ...
# 나우콘텐츠                     54
# 위드시네마                     46
# 사람과 사람들                   42
# 고구마공작소                     8
# 인피니티엔터테인먼트                 2
#
# [169 rows x 1 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))

sns.kdeplot(df_train_distributor_group['box_off_num'], ax=ax)

plt.show()

# %%
df_train_distributor_group.describe()
# Out:
#        box_off_num
# count          169
# mean     2,514,255
# std     13,178,943
# min              2
# 25%          1,351
# 50%         10,795
# 75%        126,416
# max    116,788,093

# %% [markdown]
# - 메이저, 준메이저, 무명으로 나눠 보자

# %%
def distributor_set(x):
    if x < 10795:
        return 1 # 무명
    elif x < 126416:
        return 2 # 준메이저
    else:
        return 3 # 메이저

# %%
df_train_distributor_group['distributor_en'] = df_train_distributor_group['box_off_num'].apply(distributor_set)
df_train_distributor_group
# Out:
#                  box_off_num  distributor_en
# distributor
# CJ 엔터테인먼트          116788093               3
# (주)쇼박스              88053064               3
# (주)NEW              65532145               3
# 롯데엔터테인먼트            64383745               3
# CJ E&M Pictures      8244674               3
# ...                      ...             ...
# 나우콘텐츠                     54               1
# 위드시네마                     46               1
# 사람과 사람들                   42               1
# 고구마공작소                     8               1
# 인피니티엔터테인먼트                 2               1
#
# [169 rows x 2 columns]

# %%
df_train_distributor_group.groupby('distributor_en').count()
# Out:
#                 box_off_num
# distributor_en
# 1                        84
# 2                        42
# 3                        43

# %%
# 번외
# 실제로 지금 시점의 데이터 분석을 한다면 국내 배급사 매출 순위와 일치하는지 확인해보는 것도 방법이다.
# http://www.cine21.com/rank/boxoffice/company/?cs_type=distributor
# 씨네21에서 2022-12-22 기준 1년 MAT로 확인해 본 배급사 순위는 아래와 같다.
Image('distributor_ranking_22-12.png')

# %% [markdown]
# ## genre
# - 장르는 취향의 차이이므로 관객 수와의 상관관계는 낮을 것으로 생각된다.
# - 다만, 액션이나 드라마 같은 장르는 비교적 대중적이므로 스릴러와 같은 장르에 비해서는 더 인기가 있을 것으로 생각되는데 확인해보자.

# %%
df_train['genre'].unique()
# Out:
# array(['액션', '느와르', '코미디', '다큐멘터리', '뮤지컬', '드라마', '멜로/로맨스', '공포', '서스펜스',
#        '애니메이션', '미스터리', 'SF'], dtype=object)

# %% [markdown]
# - 대략 다 다른 것 같아 보이지만 공포, 서스펜스 같은 장르는 비슷해서 묶을 수 있을 것 같다.

# %%
df_train['genre'].value_counts()
# Out:
# 드라마       221
# 다큐멘터리      93
# 멜로/로맨스     78
# 코미디        53
# 공포         42
# 액션         28
# 느와르        27
# 애니메이션      21
# 미스터리       17
# SF         13
# 뮤지컬         5
# 서스펜스        2
# Name: genre, dtype: int64

# %% [markdown]
# - 미스터리, SF, 뮤지컬, 서스펜스는 데이터 갯수가 적다.
# - 액션과 느와르는 같이 묶어도 될 것 같다.
# - 영화라는 예술 관점에서 봤을 때는 모든 장르가 하나하나 뚜렷한 특색을 가진다. 하지만 우리가 예측하려는 label은 '영화 관객 수'인데, 관객들은 영화를 볼 때 그렇게까지 세분화해서 장르를 구분하지 않을 것 같다. 영화를 보러 가는 이유와 TPO를 고려하여 비슷한 것끼리 묶어도 될 것 같다.

# %% [markdown]
# ## release_time
# - 개봉일
# - 영화 흥행에 개봉 일정은 매우 중요한 요소이다. 이 데이터에서 개봉일이 어떤 계절성을 가지는지 알아보자.

# %%
df_train_time = df_train[['release_time','box_off_num']].set_index('release_time').sort_index()
df_train_time
# Out:
#               box_off_num
# release_time
# 2010-01-02            353
# 2010-01-14            791
# 2010-01-14         143458
# 2010-01-14          27083
# 2010-01-14         155281
# ...                   ...
# 2015-12-17           1599
# 2015-12-24            329
# 2015-12-30         627586
# 2015-12-31        2084844
# 2015-12-31            339
#
# [600 rows x 1 columns]

# %%
df_train_time.plot(figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='release_time'>

# %% [markdown]
# - 이렇게 일자별로 보니 알 수가 없다. 월별로 묶어 보자

# %%
df_train_time['datetime'] = pd.to_datetime(df_train_time.index)
df_train_time['year'] = df_train_time['datetime'].dt.year
df_train_time['month'] = df_train_time['datetime'].dt.month
df_train_time['day'] = df_train_time['datetime'].dt.day_name()
df_train_time['yearmonth'] = df_train_time['datetime'].dt.to_period('M')
df_train_time
# Out:
#               box_off_num   datetime  year  month        day yearmonth
# release_time
# 2010-01-02            353 2010-01-02  2010      1   Saturday   2010-01
# 2010-01-14            791 2010-01-14  2010      1   Thursday   2010-01
# 2010-01-14         143458 2010-01-14  2010      1   Thursday   2010-01
# 2010-01-14          27083 2010-01-14  2010      1   Thursday   2010-01
# 2010-01-14         155281 2010-01-14  2010      1   Thursday   2010-01
# ...                   ...        ...   ...    ...        ...       ...
# 2015-12-17           1599 2015-12-17  2015     12   Thursday   2015-12
# 2015-12-24            329 2015-12-24  2015     12   Thursday   2015-12
# 2015-12-30         627586 2015-12-30  2015     12  Wednesday   2015-12
# 2015-12-31        2084844 2015-12-31  2015     12   Thursday   2015-12
# 2015-12-31            339 2015-12-31  2015     12   Thursday   2015-12
#
# [600 rows x 6 columns]

# %%
# 연도 테이블
df_year = df_train_time.groupby('year')[['box_off_num']].sum().reset_index()
df_year
# Out:
#    year  box_off_num
# 0  2010     48749235
# 1  2011     50309371
# 2  2012     83223817
# 3  2013     95698992
# 4  2014     75423331
# 5  2015     71504305

# %%
# 월별 테이블
df_yearmonth = df_train_time.groupby(['yearmonth','year','month'])[['box_off_num']].sum().reset_index()
df_yearmonth
# Out:
#    yearmonth  year  month  box_off_num
# 0    2010-01  2010      1      1520657
# 1    2010-02  2010      2        10232
# 2    2010-03  2010      3      1548312
# 3    2010-04  2010      4      1964416
# 4    2010-05  2010      5      3357253
# ..       ...   ...    ...          ...
# 67   2015-08  2015      8      3054825
# 68   2015-09  2015      9      4028216
# 69   2015-10  2015     10      4564507
# 70   2015-11  2015     11     13513754
# 71   2015-12  2015     12     13039798
#
# [72 rows x 4 columns]

# %%
df_yearmonth[df_yearmonth['year'] == 2010]
# Out:
#    yearmonth  year  month  box_off_num
# 0    2010-01  2010      1      1520657
# 1    2010-02  2010      2        10232
# 2    2010-03  2010      3      1548312
# 3    2010-04  2010      4      1964416
# 4    2010-05  2010      5      3357253
# 5    2010-06  2010      6      2998743
# 6    2010-07  2010      7      5933593
# 7    2010-08  2010      8      8352713
# 8    2010-09  2010      9      6434789
# 9    2010-10  2010     10      4112059
# 10   2010-11  2010     11      3559982
# 11   2010-12  2010     12      8956486

# %%
# 요일별 테이블
df_day = df_train_time.groupby('day')[['box_off_num']].sum().reset_index()
df_day = df_day.reindex([1, 4, 5, 3, 0, 2], axis='index')
df_day
# Out:
#          day  box_off_num
# 1     Monday         1736
# 4    Tuesday      5183138
# 5  Wednesday    239433802
# 3   Thursday    180192720
# 0     Friday        97302
# 2   Saturday          353

# %%
# year, day 시각화
fig, ax = plt.subplots(2, 1, figsize=(20, 12))

ax[0].plot(df_year['year'], df_year['box_off_num'])
ax[0].set_title('box_off_num by Year')
ax[0].set_ylim(0,100000000)

ax[1].plot(df_day['day'], df_day['box_off_num'])
ax[1].set_title('box_off_num by Days')

plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.35)

plt.show()

# %% [markdown]
# - 연도별로 계절성이 드러난다. 2013년에 정점을 찍고 2014년부터 감소하는 추세이다. 다만, 경제 환경과 영화 산업 등 외부 요인에 따른 가능성도 있을 수 있으므로 연도가 큰 의미를 가진다고 보기 어려울 수도 있다.
# - 요일별로는 확연히 차이가 나므로, 개봉일에 따라 영화 관객 수를 예측하는 데 도움이 될 것이다. 수~목요일에 영화가 개봉하므로 가장 관객 수가 많다.

# %%
# yearmonth 시각화
fig, ax = plt.subplots(3, 2, figsize=(25, 20))

ax[0,0].plot(df_yearmonth[df_yearmonth['year'] == 2010]['month'], df_yearmonth[df_yearmonth['year'] == 2010]['box_off_num'])
ax[0,0].set_title('box_off_num by Month(2010)')

ax[1,0].plot(df_yearmonth[df_yearmonth['year'] == 2011]['month'], df_yearmonth[df_yearmonth['year'] == 2011]['box_off_num'])
ax[1,0].set_title('box_off_num by Month(2011)')

ax[2,0].plot(df_yearmonth[df_yearmonth['year'] == 2012]['month'], df_yearmonth[df_yearmonth['year'] == 2012]['box_off_num'])
ax[2,0].set_title('box_off_num by Month(2012)')

ax[0,1].plot(df_yearmonth[df_yearmonth['year'] == 2013]['month'], df_yearmonth[df_yearmonth['year'] == 2013]['box_off_num'])
ax[0,1].set_title('box_off_num by Month(2013)')

ax[1,1].plot(df_yearmonth[df_yearmonth['year'] == 2014]['month'], df_yearmonth[df_yearmonth['year'] == 2014]['box_off_num'])
ax[1,1].set_title('box_off_num by Month(2014)')

ax[2,1].plot(df_yearmonth[df_yearmonth['year'] == 2015]['month'], df_yearmonth[df_yearmonth['year'] == 2015]['box_off_num'])
ax[2,1].set_title('box_off_num by Month(2015)')

plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.2)

plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(22, 8))

for i in range(2010, 2016):
    plt.plot(df_yearmonth[df_yearmonth['year'] == i]['month'], df_yearmonth[df_yearmonth['year'] == i]['box_off_num'])

plt.title('box_off_num by Month')

plt.show()

# %% [markdown]
# - 월별로 봤을 때는 12-1월, 7-8월에 높은 것으로 나타난다.
# - 날씨가 너무 덥거나 추울 때 사람들은 실내에 있는 영화관을 많이 찾게 되는걸까?

# %% [markdown]
# ## time
# - 상영시간 (분)
# - 상영시간은 분포에 따라 1분 단위로 달라진다기보다는, 심리적 저항선에 따라 달라질 것 같다.
# - 가정: 상영시간은 120분을 기준을 초과하는 경우 관객 수가 비교적 적고, 100~120분일 떄 가장 많으며, 100분 미만이면 적을 것 같다. 확인해보자.

# %%
df_train.head()
# Out:
#        title   distributor genre release_time  time screening_rat director  \
# 0     개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1       내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2  은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3   나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4       불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
#
#    dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# 0             NaN             0         91          2        23398
# 1       1,161,602             2        387          3      7072501
# 2         220,775             4        343          4      6959083
# 3          23,894             2         20          6       217866
# 4               1             1        251          2       483387

# %%
df_train_time = df_train[['time','box_off_num']].sort_values('time').reset_index(drop=True)
df_train_time
# Out:
#      time  box_off_num
# 0      45         2919
# 1      60          328
# 2      61           71
# 3      61          188
# 4      62          152
# ..    ...          ...
# 595   153      1744585
# 596   156      2260512
# 597   163      3350311
# 598   166         4398
# 599   180      2084844
#
# [600 rows x 2 columns]

# %%
df_train_time.describe()
# Out:
#        time  box_off_num
# count   600          600
# mean    101      708,182
# std      18    1,828,006
# min      45            1
# 25%      89        1,297
# 50%     100       12,591
# 75%     114      479,887
# max     180   14,262,766

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))

plt.scatter(df_train_time['time'], df_train_time['box_off_num'])

plt.show()

# %% [markdown]
# - 120~140분 사이의 영화가 많은 관객수를 모은 것을 볼 수 있다.
# - 140분 이상은 데이터 수 자체가 너무 적다.

# %%
# 100분 이하인 것들만 확인
df_train_time[df_train_time['time'] < 100]
# Out:
#      time  box_off_num
# 0      45         2919
# 1      60          328
# 2      61           71
# 3      61          188
# 4      62          152
# ..    ...          ...
# 293    99          600
# 294    99          542
# 295    99        13190
# 296    99          339
# 297    99          163
#
# [298 rows x 2 columns]

# %%
# 함수 구현
def time_set(x):
    if x < 100:
        return 1 # 하
    elif x < 121:
        return 2 # 중
    elif x < 141:
        return 3 # 상
    else:
        return 1 # 하

# %%
df_train_time['time_en'] = df_train_time['time'].apply(time_set)

# %%
pd.pivot_table(df_train_time[['time_en','box_off_num']], index='time_en', aggfunc=['count','sum'])
# Out:
#               count         sum
#         box_off_num box_off_num
# time_en
# 1               307    35203954
# 2               222   167591302
# 3                71   222113795

# %% [markdown]
# ## screening_rat
# - 상영등급

# %%
pd.pivot_table(df_train[['screening_rat','box_off_num']], index=['screening_rat'], aggfunc=['count','sum'])
# Out:
#                     count         sum
#               box_off_num box_off_num
# screening_rat
# 12세 관람가               102    86188052
# 15세 관람가               202   251998766
# 전체 관람가                 92    12429242
# 청소년 관람불가              204    74292991

# %% [markdown]
# ## director, dir_prev_bfnum, dir_prev_num
# - director: 감독 이름
# - dir_prev_bfnum: 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화에서의 평균 관객수 (단 관객수가 알려지지 않은 영화 제외)
# - dir_prev_num: 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화의 개수 (단 관객수가 알려지지 않은 영화 제외)
# - [가정]
# - 감독 이름을 이전 관객 수,와 영화 수와 연관지어 알아보자.
# - 메이저, 준메이저 등으로 구분지을 수 있을까?

# %%
# 앞서 dir_prev_bfnum 변수에는 결측치가 많은 것을 확인했었다. drop해야 할까?
# 왜 null인지 확인해 보자.
print('dir_prev_bfnum의 결측률:', df_train['dir_prev_bfnum'].isnull().sum() / len(df_train['dir_prev_bfnum']))
# Out:
# dir_prev_bfnum의 결측률: 0.55

# %%
df_train[(df_train['dir_prev_bfnum'].isnull()) & (df_train['dir_prev_num'] == 0)]
# Out:
#                title      distributor   genre release_time  time  \
# 0             개들의 전쟁         롯데엔터테인먼트      액션   2012-11-22    96
# 6               길위에서             백두대간   다큐멘터리   2013-05-23   104
# 8    1789, 바스티유의 연인들  유니버설픽쳐스인터내셔널코리아     뮤지컬   2014-09-18   129
# 9              청춘그루브           (주)두타연     드라마   2012-03-15    94
# 10            AV 아이돌        (주) 케이알씨지  멜로/로맨스   2015-07-27    89
# ..               ...              ...     ...          ...   ...
# 593       낭만파 남편의 편지             퍼스트런    미스터리   2013-09-12    97
# 594         오빠가 돌아왔다        (주)마운틴픽쳐스     코미디   2014-03-20    94
# 597            살인의 강        (주)마운틴픽쳐스      공포   2010-09-30    99
# 598           악의 연대기        CJ 엔터테인먼트     느와르   2015-05-14   102
# 599              베를린        CJ 엔터테인먼트      액션   2013-01-30   120
#
#     screening_rat director  dir_prev_bfnum  dir_prev_num  num_staff  \
# 0        청소년 관람불가      조병옥             NaN             0         91
# 6          전체 관람가      이창재             NaN             0         32
# 8          전체 관람가      정성복             NaN             0          3
# 9         15세 관람가      변성현             NaN             0        138
# 10       청소년 관람불가   조조 히데오             NaN             0          0
# ..            ...      ...             ...           ...        ...
# 593      청소년 관람불가      최위안             NaN             0          5
# 594      청소년 관람불가      노진수             NaN             0         37
# 597      청소년 관람불가      김대현             NaN             0        123
# 598       15세 관람가      백운학             NaN             0        431
# 599       15세 관람가      류승완             NaN             0        363
#
#      num_actor  box_off_num
# 0            2        23398
# 6            5        53526
# 8            5         4778
# 9            3          868
# 10           4          745
# ..         ...          ...
# 593          3         1132
# 594          5         1958
# 597          4         2475
# 598          4      2192525
# 599          5      7166532
#
# [330 rows x 12 columns]

# %% [markdown]
# - null값인 데이터의 dir_prev_num, 즉 이전에 참여한 영화의 갯수가 0인 것을 알 수 있다.
# - 일반적으로 측정되거나 조사된 값에서 55%가 비어 있다면 유의미한 데이터라고 보기는 어려울 수 있다.
# - 하지만, 해당 변수는 감독이 영화를 만들기 전 제작에 참여한 영화에서의 평균 관객수로, 이전에 영화 제작에 참여하지 않은 신인 감독의 경우 0이 나오게 될 수도 있다.
# - 적절히 구간을 나누어 변수로 만들어보자.

# %%
heatmap_data = df_train[['box_off_num','dir_prev_bfnum','dir_prev_num']]
heatmap_data.corr()
# Out:
#                 box_off_num  dir_prev_bfnum  dir_prev_num
# box_off_num               1               0             0
# dir_prev_bfnum            0               1             0
# dir_prev_num              0               0             1

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(6, 5))
plt.title('Pearson Correalation of Features', y=1.05, size=15)
sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0
            , square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={'size': 16}, fmt='.2f')
# Out:
# <AxesSubplot:title={'center':'Pearson Correalation of Features'}>

# %%
# 한 명의 감독이 많으면 7개의 영화에 참여했다.
df_train['director'].value_counts().sort_values()
# Out:
# 김재환         1
# 최경석         1
# 이해준         1
# 하마구치 류스케    1
# 오기환         1
#            ..
# 노진수         4
# 우민호         4
# 신재호         4
# 장률          4
# 홍상수         7
# Name: director, Length: 472, dtype: int64

# %%
df_train_dir = df_train.groupby('director', as_index=False)['dir_prev_bfnum','dir_prev_num'] \
                .sum().sort_values(by='dir_prev_bfnum', ascending=False).reset_index(drop=True)
df_train_dir
# Out:
#     director  dir_prev_bfnum  dir_prev_num
# 0        고구마      17,615,314             1
# 1        강형철      16,061,870             3
# 2        김민석       8,801,639             2
# 3        심형래       7,855,474             1
# 4        김상진       7,815,569             8
# ..       ...             ...           ...
# 467      백승화               0             0
# 468      백승기               0             0
# 469      백동훈               0             0
# 470      배창호               0             0
# 471      황철민               0             0
#
# [472 rows x 3 columns]

# %%
df_train_dir.describe()
# Out:
#        dir_prev_bfnum  dir_prev_num
# count             472           472
# mean          600,889             1
# std         1,669,276             2
# min                 0             0
# 25%                 0             0
# 50%                 0             0
# 75%           469,236             2
# max        17,615,314             9

# %%
df_train_dir[df_train_dir['dir_prev_bfnum'] > 0]
# Out:
#     director  dir_prev_bfnum  dir_prev_num
# 0        고구마      17,615,314             1
# 1        강형철      16,061,870             3
# 2        김민석       8,801,639             2
# 3        심형래       7,855,474             1
# 4        김상진       7,815,569             8
# ..       ...             ...           ...
# 217      배형준              19             2
# 218      주경중              17             1
# 219      정용주               8             1
# 220      이성은               7             1
# 221      신근호               1             1
#
# [222 rows x 3 columns]

# %%
df_train_dir[df_train_dir['dir_prev_bfnum'] > 0].describe()
# Out:
#        dir_prev_bfnum  dir_prev_num
# count             222           222
# mean        1,277,566             2
# std         2,251,710             2
# min                 1             1
# 25%            20,853             1
# 50%           511,867             2
# 75%         1,523,155             3
# max        17,615,314             9

# %% [markdown]
# - 영화감독이 신인인지, 아마추어인지, 프로인지, 거장인지 나누어 보자

# %%
# 함수 구현
def director_set(x):
    if x == 0:
        return 1 # 신인
    elif x < 511867:
        return 2 # 아마추어
    elif x < 1523155:
        return 3 # 프로
    else:
        return 4 # 거장

# %%
df_train_dir['director_en'] = df_train_dir['dir_prev_bfnum'].apply(director_set)
df_train_dir
# Out:
#     director  dir_prev_bfnum  dir_prev_num  director_en
# 0        고구마      17,615,314             1            4
# 1        강형철      16,061,870             3            4
# 2        김민석       8,801,639             2            4
# 3        심형래       7,855,474             1            4
# 4        김상진       7,815,569             8            4
# ..       ...             ...           ...          ...
# 467      백승화               0             0            1
# 468      백승기               0             0            1
# 469      백동훈               0             0            1
# 470      배창호               0             0            1
# 471      황철민               0             0            1
#
# [472 rows x 4 columns]

# %% [markdown]
# - 이렇게 구분하는 경우 train 데이터에서는 잘 구분될 수 있지만 새로운 데이터에서는 의미가 없을 수 있다.
# - 거장 감독이지만 train set에 없다면 새로운 데이터를 검증하기 어려우며, 신인 감독인 경우에도 마찬가지일 수 있다.

# %% [markdown]
# ## num_staff
# - 스태프 수
# - 스태프 수가 많을수록 제작비가 많이 들어갔다는 의미이니, 관객을 많이 모을 확률이 높은걸까?
# - 스태프 수에 따라 소형, 중형, 대형으로 나누어 보자

# %%
df_train_staff = df_train[['num_staff','box_off_num']]
df_train_staff
# Out:
#      num_staff  box_off_num
# 0           91        23398
# 1          387      7072501
# 2          343      6959083
# 3           20       217866
# 4          251       483387
# ..         ...          ...
# 595        510      1475091
# 596        286      1716438
# 597        123         2475
# 598        431      2192525
# 599        363      7166532
#
# [600 rows x 2 columns]

# %%
df_train_staff.describe()
# Out:
#        num_staff  box_off_num
# count        600          600
# mean         151      708,182
# std          166    1,828,006
# min            0            1
# 25%           17        1,297
# 50%           82       12,591
# 75%          264      479,887
# max          869   14,262,766

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 4))

plt.scatter(df_train_staff['num_staff'], df_train_time['box_off_num'])

plt.show()

# %%
# 함수 구현
def num_staff_set(x):
    if x < 82:
        return 1 # 소형
    elif x < 264:
        return 2 # 중형
    else:
        return 3 # 대형

# %%
df_train_staff['num_staff_en'] = df_train_staff['num_staff'].apply(num_staff_set)
df_train_staff
# Out:
#      num_staff  box_off_num  num_staff_en
# 0           91        23398             2
# 1          387      7072501             3
# 2          343      6959083             3
# 3           20       217866             1
# 4          251       483387             2
# ..         ...          ...           ...
# 595        510      1475091             3
# 596        286      1716438             3
# 597        123         2475             2
# 598        431      2192525             3
# 599        363      7166532             3
#
# [600 rows x 3 columns]

# %% [markdown]
# ## num_actor
# - 주연 배우 수

# %%
df_train[['num_actor','box_off_num']]
# Out:
#      num_actor  box_off_num
# 0            2        23398
# 1            3      7072501
# 2            4      6959083
# 3            6       217866
# 4            2       483387
# ..         ...          ...
# 595          7      1475091
# 596          6      1716438
# 597          4         2475
# 598          4      2192525
# 599          5      7166532
#
# [600 rows x 2 columns]

# %%
df_train['num_actor'].describe()
# Out:
# count   600
# mean      4
# std       2
# min       0
# 25%       2
# 50%       3
# 75%       4
# max      25
# Name: num_actor, dtype: float64

# %% [markdown]
# - 주연 배우의 수는 대부분 2명 수준이므로 큰 의미를 가지지 않을 것 같다.

# %% [markdown]
# ## 결론
# - 총 11개의 독립변수에 대해 알아보았다.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           600 non-null    object
#  1   distributor     600 non-null    object
#  2   genre           600 non-null    object
#  3   release_time    600 non-null    object
#  4   time            600 non-null    int64
#  5   screening_rat   600 non-null    object
#  6   director        600 non-null    object
#  7   dir_prev_bfnum  270 non-null    float64
#  8   dir_prev_num    600 non-null    int64
#  9   num_staff       600 non-null    int64
#  10  num_actor       600 non-null    int64
#  11  box_off_num     600 non-null    int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 56.4+ KB

# %% [markdown]
# 1. title
# - drop
# 2. distributor
# - 메이저, 준메이저, 무명 배급사로 구분하여 새로운 컬럼 생성
# 3. genre
# - 공포+미스터리+서스펜스, 액션+느와르는 합쳐서 새로운 컬럼 생성
# 4. release_time
# - 성수기, 준성수기, 비성수기로 구분하여 새로운 컬럼 생성
# 5. time
# - 선호도 상, 중, 하로 구분하여 새로운 컬럼 생성
# 6. screening_rat
# - 랭크로 인코딩
# 7. director, dir_prev_bfnum, dir_prev_num
# - drop
# 8. num_staff
# - 스태프 수에 따라 소형, 중형, 대형으로 나누어 컬럼 생성
# 9. num_actor
# - drop

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## 분석에 사용할 컬럼만 선별

# %% [markdown]
# - 다시 하나씩 보면서 전처리

# %% [markdown]
# ### title

# %%
df_train = df_train.drop('title', axis=1)
df_test = df_test.drop('title', axis=1)

# %% [markdown]
# ### distributor

# %%
# 이 데이터를 distributor를 기준으로 left join해서 넣어보자
df_train_distributor_group
# Out:
#                  box_off_num  distributor_en
# distributor
# CJ 엔터테인먼트          116788093               3
# (주)쇼박스              88053064               3
# (주)NEW              65532145               3
# 롯데엔터테인먼트            64383745               3
# CJ E&M Pictures      8244674               3
# ...                      ...             ...
# 나우콘텐츠                     54               1
# 위드시네마                     46               1
# 사람과 사람들                   42               1
# 고구마공작소                     8               1
# 인피니티엔터테인먼트                 2               1
#
# [169 rows x 2 columns]

# %%
df_train = df_train.merge(df_train_distributor_group['distributor_en'], how='left', on='distributor')

# %%
df_train = df_train.drop('distributor', axis=1)

# %%
df_test = df_test.merge(df_train_distributor_group['distributor_en'], how='left', on='distributor')

# %%
df_test.isnull().sum()
# Out:
# distributor         0
# genre               0
# release_time        0
# time                0
# screening_rat       0
# director            0
# dir_prev_bfnum    136
# dir_prev_num        0
# num_staff           0
# num_actor           0
# distributor_en     36
# dtype: int64

# %% [markdown]
# - test set의 distributor_en에는 36개의 null 값이 있는데, 이 값들은 '무명'으로 채워준다.

# %%
df_test['distributor_en'] = df_test['distributor_en'].fillna('1')

# %%
df_test.isnull().sum()
# Out:
# distributor         0
# genre               0
# release_time        0
# time                0
# screening_rat       0
# director            0
# dir_prev_bfnum    136
# dir_prev_num        0
# num_staff           0
# num_actor           0
# distributor_en      0
# dtype: int64

# %%
df_test = df_test.drop('distributor', axis=1)

# %%
df_test.head()
# Out:
#     genre release_time  time screening_rat director  dir_prev_bfnum  \
# 0     느와르   2010-01-07   125      청소년 관람불가      김형준         300,529
# 1  멜로/로맨스   2010-01-14   113       12세 관람가      이광재         342,700
# 2     드라마   2010-01-28   115       12세 관람가      강대규       4,206,611
# 3      액션   2010-02-04   116       15세 관람가       장훈         691,342
# 4      공포   2010-02-18   110       15세 관람가      권호영          31,738
#
#    dir_prev_num  num_staff  num_actor distributor_en
# 0             2        304          3              3
# 1             4        275          3              3
# 2             3        419          7              3
# 3             2        408          2              3
# 4             1        380          1              3

# %% [markdown]
# ### genre
# - 공포+미스터리+서스펜스, 액션+느와르는 합쳐서 새로운 컬럼 생성

# %%
def genre_set(x):
    if (x == '공포') or (x == '미스터리') or (x == '서스펜스'):
        return '스릴러'
    elif (x == '액션') or (x == '느와르'):
        return '블록버스터'
    else:
        return x

# %%
df_train['genre_en'] = df_train['genre'].apply(genre_set)

# %%
df_test['genre_en'] = df_test['genre'].apply(genre_set)

# %%
# 장르 인코딩
df_train.groupby('genre_en')['box_off_num'].mean().sort_values()
# Out:
# genre_en
# 뮤지컬          6,627
# 다큐멘터리       67,172
# 애니메이션      181,927
# 멜로/로맨스     425,968
# 스릴러        556,533
# 드라마        625,690
# 코미디      1,193,914
# SF       1,788,346
# 블록버스터    2,233,292
# Name: box_off_num, dtype: float64

# %%
df_train['genre_en'] = df_train.genre_en.map({'뮤지컬' : 1, '다큐멘터리' : 2, '애니메이션' : 3, '멜로/로맨스' : 4, '스릴러' : 5,
                                      '드라마' : 6, '코미디' : 7, 'SF' : 8, '블록버스터' : 9})

# %%
df_test['genre_en'] = df_test.genre_en.map({'뮤지컬' : 1, '다큐멘터리' : 2, '애니메이션' : 3, '멜로/로맨스' : 4, '스릴러' : 5,
                                      '드라마' : 6, '코미디' : 7, 'SF' : 8, '블록버스터' : 9})

# %%
df_train = df_train.drop('genre', axis=1)
df_test = df_test.drop('genre', axis=1)

# %% [markdown]
# ### release_time

# %% [markdown]
# - 요일별 성수기는 수-목
# - 월별 성수기는 7-8월, 12-1월
# - 요일별 인기여부 컬럼 추가

# %%
# year 컬럼 추가

# %%
df_train['year'] = pd.to_datetime(df_train['release_time']).dt.year

# %%
df_test['year'] = pd.to_datetime(df_test['release_time']).dt.year

# %%
# month 컬럼 추가

# %%
df_train['month'] = pd.to_datetime(df_train['release_time']).dt.month

# %%
df_test['month'] = pd.to_datetime(df_test['release_time']).dt.month

# %%
# drop

# %%
df_train = df_train.drop('release_time', axis=1)
df_test = df_test.drop('release_time', axis=1)

# %% [markdown]
# ### time

# %% [markdown]
# - 데이터 살펴보기에서 썼던 time_set 함수를 활용한다.

# %%
df_train['time_en'] = df_train['time'].apply(time_set)
df_test['time_en'] = df_test['time'].apply(time_set)

# %%
df_train = df_train.drop('time', axis=1)
df_test = df_test.drop('time', axis=1)

# %% [markdown]
# ### screening_rat

# %%
df_train.groupby('screening_rat')['box_off_num'].mean().sort_values()
# Out:
# screening_rat
# 전체 관람가       135,100
# 청소년 관람불가     364,181
# 12세 관람가      844,981
# 15세 관람가    1,247,519
# Name: box_off_num, dtype: float64

# %%
def screening_set(x):
    if x == '전체 관람가':
        return 1
    elif x == '청소년 관람불가':
        return 2
    elif x == '12세 관람가':
        return 3
    else:
        return 4

# %%
df_train['screening_rat_en'] = df_train['screening_rat'].apply(screening_set)

# %%
df_test['screening_rat_en'] = df_test['screening_rat'].apply(screening_set)

# %%
df_train = df_train.drop('screening_rat', axis=1)
df_test = df_test.drop('screening_rat', axis=1)

# %% [markdown]
# ### director

# %%
df_train = df_train.drop('director', axis=1)
df_test = df_test.drop('director', axis=1)

# %% [markdown]
# ### dir_prev_bfnum

# %%
df_train = df_train.drop('dir_prev_bfnum', axis=1)
df_test = df_test.drop('dir_prev_bfnum', axis=1)

# %% [markdown]
# ### dir_prev_num

# %%
df_train = df_train.drop('dir_prev_num', axis=1)
df_test = df_test.drop('dir_prev_num', axis=1)

# %% [markdown]
# ### num_actor

# %%
df_train = df_train.drop('num_actor', axis=1)
df_test = df_test.drop('num_actor', axis=1)

# %% [markdown]
# ### 컬럼 선별

# %%
df_train.head(3)
# Out:
#    num_staff  box_off_num  distributor_en  genre_en  month  time_en  \
# 0         91        23398               3         9     11        1
# 1        387      7072501               3         9     11        3
# 2        343      6959083               3         9      6        3
#
#    screening_rat_en
# 0                 2
# 1                 2
# 2                 4

# %%
df_test.head(3)
# Out:
#    num_staff distributor_en  genre_en  month  time_en  screening_rat_en
# 0        304              3         9      1        3                 2
# 1        275              3         4      1        2                 3
# 2        419              3         6      1        2                 3

# %% [markdown]
# # Modeling - Prediction - Submission

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Modeling

# %%
train_X = df_train.drop(['box_off_num'],axis= 1)
train_y = df_train['box_off_num']

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_y, test_size=0.33, random_state=42)

# %%
def randomized_search_reg(params, runs=16, reg=RandomForestRegressor(random_state=2, n_jobs=-1)):
    rand_reg = RandomizedSearchCV(reg, params, n_iter=runs, scoring='neg_mean_squared_error',
                                 cv=10, n_jobs=-1, random_state=2)
    rand_reg.fit(X_train, y_train)
    best_model = rand_reg.best_estimator_
    best_params = rand_reg.best_params_
    print('Best Parameter', best_params)
    
    best_score = np.sqrt(-rand_reg.best_score_)
    print('Train Score: {:.3f}'.format(best_score))
    
    y_pred = best_model.predict(X_test)
    rmse_test = MSE(y_test, y_pred)**0.5
    print('Test Set Score: {:.3f}'.format(rmse_test))
    
    return best_model

# %%
rs = randomized_search_reg(
    params={'min_samples_leaf':[1,2,4,6,8,10,20,30],
            'min_impurity_decrease':[0.0, 0.01, 0.05, 0.10, 0.15, 0.2],
            'max_features':['sqrt', 0.8, 0.7, 0.6, 0.5, 0.4],
            'max_depth':[None,4,6,8,10,12,15,20],
            'n_estimators':[100]}, 
    runs=20)
# Out:
# Best Parameter {'n_estimators': 100, 'min_samples_leaf': 10, 'min_impurity_decrease': 0.0, 'max_features': 0.5, 'max_depth': 10}
# Train Score: 1561875.287
# Test Set Score: 1219069.965

# %%
rf = RandomForestRegressor(n_estimators=100, min_samples_leaf=8, min_impurity_decrease=0.0, 
                           max_features=0.6, max_depth=12, n_jobs=-1, 
                           random_state=2)
   
scores = cross_val_score(rf, train_X, train_y, scoring='neg_mean_squared_error', cv=10)
rmse = np.sqrt(-scores)

print('RMSE:', np.round(rmse, 3))
print('RMSE 평균: %0.3f' % (rmse.mean()))
# Out:
# RMSE: [ 846706.87  1324662.056 1378564.506  939236.962  957914.553 1037219.352
#  1994213.14  1690182.941 2225542.659 1360399.146]
# RMSE 평균: 1375464.218

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=12, max_features=0.6, min_samples_leaf=8,
#                       n_jobs=-1, random_state=2)

# %% [markdown]
# ### Prediction

# %%
prediction = rf.predict(df_test)

# %% [markdown]
# ### Submission

# %%
submission = pd.read_csv('data/submission.csv')
submission.head(2)
# Out:
#          title  box_off_num
# 0       용서는 없다            0
# 1  아빠가 여자를 좋아해            0

# %%
submission['box_off_num'] = prediction
submission.head(2)
# Out:
#          title  box_off_num
# 0       용서는 없다    3,516,366
# 1  아빠가 여자를 좋아해    1,043,157

# %%
version = 'v4'
submission_title = version+'_movie_submission_'+datetime.datetime.now().strftime("%y%m%d_%H%M")+'_randomforest'
submission_title
# Out:
# 'v4_movie_submission_230201_1207_randomforest'

# %%
submission.to_csv(submission_title+'.csv',index = False)
